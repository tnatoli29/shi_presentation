# %%
#Import Dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
clean_2016 = pd.read_csv('Resources/Cleaned_july_2016_data.csv')
clean_2019 = pd.read_csv('Resources/Cleaned_july_2019_data.csv')

clean_2016.head()
# Out:
#    Unnamed: 0  trip duration  start station id start station name  \
# 0           0            964              3185          City Hall
# 1           1            472              3185          City Hall
# 2           2            565              3199       Newport Pkwy
# 3           3            413              3195            Sip Ave
# 4           4            436              3202       Newport PATH
#
#    start station latitude  start station longitude  end station id  \
# 0               40.717732               -74.043845            3199
# 1               40.717732               -74.043845            3192
# 2               40.728745               -74.032108            3199
# 3               40.730743               -74.063784            3209
# 4               40.727224               -74.033759            3203
#
#      end station name  end station latitude  end station longitude  bike id  \
# 0        Newport Pkwy             40.728745             -74.032108    24706
# ...
